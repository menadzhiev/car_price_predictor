# %% [markdown]
# # Сбор данных

# %% [markdown]
# __Заметка:__ Так как парсер был упрощен и перезапущен, то собранные им данные изменились. В дальнейшей работе мы будем пользоваться данными, актуальными на 03.05.2023. Старый вариант парсера можно найти в папке "Прочее" репозитория github.

# %% [markdown]
# ### 1. Загрузим нужные библиотеки и напишем функции

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
from tqdm.notebook import tqdm


def get_soup(url: str):
    res = requests.get(url)
    return BeautifulSoup(res.content, 'html.parser')


def get_cars_hrefs(tree):
    cars = tree.find_all('a', {'class': 'vehicle-card-link'})
    return [
        {'model': car.h2.text, 'href': car.get('href')} for car in cars
    ]


def columns_maker(table):
    soup = BeautifulSoup(str(table), 'html.parser')

    dt = soup.find_all('dt')
    
    columns = []
    for i in range(len(dt)):
        columns.append(dt[i].text)

    return columns


def table_maker(table):
    soup = BeautifulSoup(str(table), 'html.parser')

    dd = soup.find_all('dd')

    res = []
    for i in range(len(dd)):
        res.append(dd[i].text.strip())
    
    return res


MAIN_URL = 'https://www.cars.com/'

# %% [markdown]
# ### 2. Соберем нужное количество данных

# %% [markdown]
# __Заметка:__ Пропишем ниже более компактный вариант реализации первого шага парсинга, но при этом оставим прошлый код, так как те данные, с которыми мы будем работать, были собраны с его помощью.

# %%
def parsing_first_step(p):
    url = MAIN_URL + f'shopping/results/?list_price_max=&makes[]=&maximum_distance=all&models[]=&page={p}&stock_type=used&zip='
    tree = get_soup(url)
    hlp = get_cars_hrefs(tree)
    data.extend(hlp)
    sleep(0.02)

# %%
data = []
for p in tqdm(range(50, 251)):
    parsing_first_step(p)
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]

# %%
cars = pd.DataFrame(data)
cars.head()
# Out:
#                             model  \
# 0  2022 Mazda CX-9 Carbon Edition
# 1       2020 Hyundai Tucson Sport
# 2          2021 Ford F-150 Raptor
# 3             2016 Acura RDX Base
# 4    2019 Ford Mustang GT Premium
#
#                                                 href
# 0  /vehicledetail/2e233c09-13a7-40fa-bc55-c62ad7e...
# 1  /vehicledetail/c7c4481a-9509-46ca-86da-0d047cf...
# 2  /vehicledetail/bf528522-adbc-479a-874a-6074213...
# 3  /vehicledetail/7d967865-4de8-48ff-a366-5016658...
# 4  /vehicledetail/407db0d2-337c-4e08-8590-6fd413c...

# %% [markdown]
# ---

# %%
url = MAIN_URL + cars['href'][4]
tree = get_soup(url)

basics = tree.find('dl', {'class': 'fancy-description-list'})
history = tree.find('section', {'class': 'sds-page-section vehicle-history-section'})

# %%
final_columns = [
    'Model',
    'href',
    'Exterior color',
    'Interior color',
    'Drivetrain',
    'MPG',
    'Fuel type',
    'Transmission',
    'Engine',
    'VIN',
    'Stock #',
    'Mileage',
    'Accidents or damage',
    '1-owner vehicle',
    'Personal use only',
    'Price'
]

# %%
cars_df = pd.DataFrame(columns=final_columns)

# %%
cars_df
# Out:
# Empty DataFrame
# Columns: [Model, href, Exterior color, Interior color, Drivetrain, MPG, Fuel type, Transmission, Engine, VIN, Stock #, Mileage, Accidents or damage, 1-owner vehicle, Personal use only, Price]
# Index: []

# %% [markdown]
# ---

# %%
def parsing_second_step(first_idx, last_idx):
    for i in tqdm(range(first_idx, last_idx + 1)):
        car = cars.iloc[i, :]
        url = MAIN_URL + car['href']
        tree = get_soup(url)
        
        basics = tree.find('dl', {'class': 'fancy-description-list'})
        history = tree.find('section', {'class': 'sds-page-section vehicle-history-section'})
        
        res = [car['model'], car['href']]
        if basics != None and history != None:    
            price = tree.find('span', {'class': 'primary-price'}).text
            res.extend(table_maker(basics))
            res.extend(table_maker(history.dl))

            if len(res) == 16:
                res = res[:-1]
            
            if len(res) == 15:
                res.append(price)
                cars_df.loc[i] = res
        
        sleep(0.02)

# %%
idx_pairs = [(0, 1000), (1001, 2000), (2001, 3000), (3001, 4214)]

# Покажем на примере первой пары, так как данные уже собраны
for i in range(1):
    first_idx, last_idx = idx_pairs[i]
    parsing_second_step(first_idx, last_idx)
# Out:
#   0%|          | 0/1001 [00:00<?, ?it/s]

# %%
cars_df.drop_duplicates(inplace=True)

# %%
cars_df
# Out:
#                                        Model  \
# 0             2022 Mazda CX-9 Carbon Edition
# 1                  2020 Hyundai Tucson Sport
# 2                     2021 Ford F-150 Raptor
# 3                        2016 Acura RDX Base
# 4               2019 Ford Mustang GT Premium
# ..                                       ...
# 990                2020 Porsche Cayenne Base
# 992                 2020 Porsche Panamera 4S
# 993  2003 Mercedes-Benz C-Class 4dr Sdn 2.6L
# 994            2023 Porsche Macan Base (PDK)
# 995                     2023 Porsche Macan T
#
#                                                   href  \
# 0    /vehicledetail/2e233c09-13a7-40fa-bc55-c62ad7e...
# 1    /vehicledetail/c7c4481a-9509-46ca-86da-0d047cf...
# 2    /vehicledetail/bf528522-adbc-479a-874a-6074213...
# 3    /vehicledetail/7d967865-4de8-48ff-a366-5016658...
# 4    /vehicledetail/407db0d2-337c-4e08-8590-6fd413c...
# ..                                                 ...
# 990  /vehicledetail/29766710-84ec-4c93-bc9d-ac00252...
# 992  /vehicledetail/6547454b-d5e9-4f02-b03e-d866a5e...
# 993  /vehicledetail/c8831633-3eb1-4e21-94de-50647ff...
# 994  /vehicledetail/077befc1-560c-450a-b04d-38aa7f8...
# 995  /vehicledetail/562508bd-b1f7-4c14-8934-2826071...
#
#               Exterior color      Interior color        Drivetrain  \
# 0    Polymetal Gray Metallic                 Red   All-wheel Drive
# 1             Stellar Silver                Gray   All-wheel Drive
# 2       Agate Black Metallic               Black  Four-wheel Drive
# 3                       Gray           Graystone   All-wheel Drive
# 4               Oxford White               Ebony  Rear-wheel Drive
# ..                       ...                 ...               ...
# 990  Quartzite Grey Metallic               Black   All-wheel Drive
# 992                    Black               Black   All-wheel Drive
# 993       Leather Upholstery  Leather Upholstery  Rear-wheel Drive
# 994                    White          Agate Grey   All-wheel Drive
# 995    Volcano Grey Metallic               Black   All-wheel Drive
#
#                                                    MPG Fuel type  \
# 0                                                    –  Gasoline
# 1    21–26\n\n\n\nBased on EPA mileage ratings. Use...  Gasoline
# 2                                                    –  Gasoline
# 3    19–28\n\n\n\nBased on EPA mileage ratings. Use...  Gasoline
# 4    15–24\n\n\n\nBased on EPA mileage ratings. Use...  Gasoline
# ..                                                 ...       ...
# 990  19–23\n\n\n\nBased on EPA mileage ratings. Use...  Gasoline
# 992  18–26\n\n\n\nBased on EPA mileage ratings. Use...  Gasoline
# 993  19–26\n\n\n\nBased on EPA mileage ratings. Use...  Gasoline
# 994                                                  –  Gasoline
# 995                                                  –  Gasoline
#
#            Transmission                                             Engine  \
# 0     6-Speed Automatic                         2.5L I4 16V GDI DOHC Turbo
# 1     6-Speed Automatic                               2.4L I4 16V GDI DOHC
# 2    10-Speed Automatic                    3.5L V6 24V PDI DOHC Twin Turbo
# 3     6-Speed Automatic                              3.5L V6 24V MPFI SOHC
# 4    10-Speed Automatic  5L V-8 port/direct injection, DOHC, Ti-VCT var...
# ..                  ...                                                ...
# 990   8-Speed Automatic                         3.0L V6 24V GDI DOHC Turbo
# 992           Automatic  2.9L V-6 gasoline direct injection, DOHC, vari...
# 993           Automatic                         2.6L V-6 engine with 168HP
# 994           Automatic                         2.0L I4 16V GDI DOHC Turbo
# 995           Automatic                         2.0L I4 16V GDI DOHC Turbo
#
#                    VIN      Stock #      Mileage Accidents or damage  \
# 0    JM3TCBDY6N0628837       M919SL    3,804 mi.       None reported
# 1    KM8J3CAL2LU204183       U22279   21,063 mi.       None reported
# 2    1FTFW1RG8MFC40141  WPMFC40141B   13,565 mi.       None reported
# 3    5J8TB4H59GL001057       001057   76,414 mi.       None reported
# 4    1FATP8FF5K5138115       P30263    1,248 mi.       None reported
# ..                 ...          ...          ...                 ...
# 990  WP1AA2AY9LDA04075     323028-1   52,908 mi.       None reported
# 992  WP0AB2A75LL140652       40025T    6,265 mi.       None reported
# 993  WDBRF61J13F354688     H212030A  206,080 mi.       None reported
# 994  WP1AA2A53PLB01192       L00214    6,171 mi.       None reported
# 995  WP1AA2A5XPLB05224       L00233    5,720 mi.       None reported
#
#     1-owner vehicle Personal use only    Price
# 0               Yes               Yes  $40,374
# 1               Yes               Yes  $24,376
# 2               Yes               Yes  $79,692
# 3                No                No  $21,487
# 4                No               Yes  $93,500
# ..              ...               ...      ...
# 990             Yes               Yes  $56,777
# 992             Yes               Yes  $92,998
# 993              No               Yes   $6,250
# 994             Yes                No  $64,500
# 995              No                No  $62,800
#
# [699 rows x 16 columns]

# %% [markdown]
# ### 3. Сохраним таблицу в файл

# %%
#cars.to_csv('cars_raw_data.csv', index=False)

# %%
#cars_df.to_csv('cars_df.csv', index=False)
